# %% [markdown]
# <a href="https://colab.research.google.com/github/isoliveira20/POS-IA/blob/main/tech_challenge_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from collections import defaultdict, Counter

teams_df = pd.read_csv('https://raw.githubusercontent.com/isoliveira20/POS-IA/refs/heads/main/tech_challenge_02/teams_dataset.csv')
tasks_df = pd.read_csv('https://raw.githubusercontent.com/isoliveira20/POS-IA/refs/heads/main/tech_challenge_02/tasks_dataset.csv')

team_info = {
    row['name']: {
        'level': row['level'],
        'stack': row['stack']
    }
    for _, row in teams_df.iterrows()
}

num_generations = 300
exploitation_prob = 0.5
population_size = len(tasks_df) * 2
sprint_days = 10
max_no_improve = 20
no_improve = 0
max_attempts_tournament = 10

base_mutation_rate = 0.05         # taxa inicial
max_mutation_rate = 0.5           # limite superior
mutation_rate = base_mutation_rate

no_improvement_threshold = 5     # quantas gerações sem melhorar antes de aumentar
best_fitness_overall = float('inf')
best_solution_overall = None

random.seed(42)
np.random.seed(42)

best_fitness_history = []
avg_fitness_history = []

level_rules = {
    'Intern': {
        'cost_multiplier': 0.5,
        'max_daily_hours': 5,
        'overload_tolerance': 0,
        'overload_penalty_multiplier': 1000,
    },
    'Junior': {
        'cost_multiplier': 0.75,
        'max_daily_hours': 7,
        'overload_tolerance': 2,
        'overload_penalty_multiplier': 500,
    },
    'Mid-level': {
        'cost_multiplier': 1.0,
        'max_daily_hours': 7,
        'overload_tolerance': 5,
        'overload_penalty_multiplier': 200,
    },
    'Senior': {
        'cost_multiplier': 1.25,
        'max_daily_hours': 7,
        'overload_tolerance': 10,
        'overload_penalty_multiplier': 100,
    },
    'Specialist': {
        'cost_multiplier': 1.5,
        'max_daily_hours': 7,
        'overload_tolerance': 10,
        'overload_penalty_multiplier': 100,
    },
}



priority_weight = {'Disaster': 5, 'Critical': 4, 'High':3, 'Medium':2, 'Low':1}

developers = teams_df['name'].tolist()

# dev é compatível
def is_compatible(dev_name, task_stack, teams_df):
    dev_stack = teams_df.loc[teams_df['name'] == dev_name, 'stack'].values[0]
    return dev_stack == task_stack

# geração para criar solução válida com priorização de tasks
def generate_random_chromosome_prioritized(tasks_df, developers, teams_df):
    chromosome = []
    # Ordena tasks da maior para menor prioridade
    tasks_sorted = tasks_df.copy()
    tasks_sorted['priority_weight'] = tasks_sorted['priority'].map(priority_weight)
    tasks_sorted = tasks_sorted.sort_values(by='priority_weight', ascending=False)

    for _, task_row in tasks_sorted.iterrows():
        task_stack = task_row['stack']
        # Devs compatíveis
        compatible_devs = [dev for dev in developers if teams_df.loc[teams_df['name'] == dev, 'stack'].values[0] == task_stack]

        if compatible_devs:
            assigned_dev = random.choice(compatible_devs)
        else: # fallback para qualquer dev
            assigned_dev = random.choice(developers)

        chromosome.append(assigned_dev)

    return chromosome

# gerar população inicial
def generate_random_chromosome_balanced(tasks_df, developers, teams_df):
    dev_hours = {dev: 0 for dev in developers}
    chromosome = []

    for _, task_row in tasks_df.iterrows():
        task_stack = task_row['stack']
        hours = task_row['estimated_hours']
        compatible_devs = [dev for dev in developers if teams_df.loc[teams_df['name']==dev, 'stack'].values[0]==task_stack]
        if compatible_devs:
            # escolhe dev compatível com menor carga atual
            assigned_dev = min(compatible_devs, key=lambda d: dev_hours[d])
        else:
            assigned_dev = min(developers, key=lambda d: dev_hours[d])

        chromosome.append(assigned_dev)
        dev_hours[assigned_dev] += hours

    return chromosome


def generate_random_chromosome_experienced(tasks_df, developers, teams_df):
    chromosome = []
    for _, task in tasks_df.iterrows():
        stack = task['stack']
        priority = task['priority']
        # Para tarefas críticas, priorize devs Senior/Specialist
        if priority in ['Disaster', 'Critical']:
            compatible_devs = [
                dev for dev in developers
                if teams_df.loc[teams_df['name'] == dev, 'stack'].values[0] == stack
                and teams_df.loc[teams_df['name'] == dev, 'level'].values[0] in ['Senior', 'Specialist']
            ]
        else:
            compatible_devs = [dev for dev in developers if teams_df.loc[teams_df['name'] == dev, 'stack'].values[0] == stack]
        if compatible_devs:
            assigned = random.choice(compatible_devs)
        else:
            assigned = random.choice(developers)
        chromosome.append(assigned)
    return chromosome


def generate_population(population_size, tasks_df, developers, teams_df):
    population_new = []
    for _ in range(population_size // 3):
        population_new.append(generate_random_chromosome_prioritized(tasks_df, developers, teams_df))
    for _ in range(population_size // 3):
        population_new.append(generate_random_chromosome_balanced(tasks_df, developers, teams_df))
    for _ in range(population_size - 2*(population_size // 3)):
        population_new.append(generate_random_chromosome_experienced(tasks_df, developers, teams_df))

    return population_new


def fitness(chromosome, tasks_df, teams_df):
    dev_hours = {dev: 0 for dev in teams_df['name']}
    dev_cost = {dev: 0 for dev in teams_df['name']}
    penalty = 0.0

    tasks_by_level = defaultdict(int)

    for task_idx, dev in enumerate(chromosome):
        task = tasks_df.iloc[task_idx]
        hours = task['estimated_hours']
        dev_info = team_info[dev]
        level = dev_info['level']
        stack = dev_info['stack']
        priority = task['priority']

        dev_hours[dev] += hours
        cost = hours * level_rules[level]['cost_multiplier']
        dev_cost[dev] += cost
        tasks_by_level[level] += 1

        priority_w = priority_weight.get(priority, 1)

        # Penalidades reescaladas
        if stack != task['stack']:
            penalty += 2 * priority_w    # antes 20 * priority_w

        if level in ['Intern', 'Junior'] and priority in ['Critical', 'Disaster']:
            penalty += 20   # antes 200

    total_cost = sum(dev_cost.values())

    overload_score = 0.0
    for dev, hours in dev_hours.items():
        dev_info = teams_df[teams_df['name'] == dev].iloc[0]
        level = dev_info['level']
        max_hours = level_rules[level]['max_daily_hours'] * sprint_days

        if hours > max_hours:
            overload = hours - level_rules[level]['max_daily_hours']
            tolerance = level_rules[level]['overload_tolerance']
            critical_overload = max(0, overload - tolerance)
            penalty += (level_rules[level]['overload_penalty_multiplier'] / 10) * critical_overload  # ex: 1000→100

            overload_score += overload / max_hours

            if level == 'Intern':
                penalty += 10 * overload    # antes 100

    hours_list = np.array(list(dev_hours.values()))
    avg_hours = np.mean(hours_list) if len(hours_list) > 0 else 0.0
    std_hours = np.std(hours_list)

    MIN_AVG_HOURS = 1e-1
    safe_avg_hours = max(avg_hours, MIN_AVG_HOURS)
    imbalance_score = std_hours / safe_avg_hours

    level_task_counts = [tasks_by_level[lvl] for lvl in ['Intern', 'Junior', 'Mid-level', 'Senior', 'Specialist']]
    distribution_penalty = np.std(level_task_counts)

    w_overload = 0.6
    w_cost = 0.08
    w_imbalance = 0.4
    w_distribution = 0.15
    w_base_penalties = 0.1

    fitness_value = (
        w_overload * overload_score +
        w_cost * total_cost +
        w_imbalance * imbalance_score +
        w_distribution * distribution_penalty +
        w_base_penalties * penalty
    )

    return fitness_value


# escolhendo os pais por torneio
def tournament_selection(population, fitnesses, k=7):
    selected = random.sample(list(zip(population, fitnesses)), k)
    selected.sort(key=lambda x: x[1])  # Menor fitness é melhor

    return selected[0][0]


# corrigir incompatibilidades
def correct_incompatibilities(chromosome, tasks_df, developers, teams_df):
    corrected_chromosome = chromosome.copy()
    task_counts = Counter(chromosome)

    for i, dev in enumerate(corrected_chromosome):
        task_stack = tasks_df.iloc[i]['stack']
        dev_stack = team_info[dev]['stack']

        if dev_stack != task_stack:
            compatible_devs = [
                d for d in developers if team_info[d]['stack'] == task_stack
            ]

            if compatible_devs:
                # Preferir quem tem menos tarefas no cromossomo original
                chosen_dev = min(compatible_devs, key=lambda d: task_counts[d])

                # Atualiza o cromossomo e os contadores
                old_dev = corrected_chromosome[i]
                corrected_chromosome[i] = chosen_dev

                task_counts[old_dev] -= 1
                task_counts[chosen_dev] += 1
            else:
                # Sem dev compatível — mantém o original
                pass

    return corrected_chromosome

def uniform_crossover(parent1, parent2):
    child = []

    for a, b in zip(parent1, parent2):
      child.append(random.choice([a, b]))

    return child

def two_point_crossover(parent1, parent2):
    size = len(parent1)

    pt1, pt2 = sorted(random.sample(range(size), 2))

    child = parent1[:pt1] + parent2[pt1:pt2] + parent1[pt2:]

    return child

# mutação
def mutate_balanced(chromosome, developers, teams_df, tasks_df, mutation_rate):
    dev_hours = {dev: 0 for dev in developers}

    if mutation_rate > base_mutation_rate:
        exploitation_prob_adap = max(0.2, exploitation_prob - 0.05)
    else:
        exploitation_prob_adap = min(0.9, exploitation_prob + 0.05)

    # Calcula carga atual
    for i, dev in enumerate(chromosome):
        dev_hours[dev] += tasks_df.iloc[i]['estimated_hours']

    for i in range(len(chromosome)):
        if random.random() < mutation_rate:
            task_stack = tasks_df.iloc[i]['stack']
            task_hours = tasks_df.iloc[i]['estimated_hours']

            compatible_devs = [
                dev for dev in developers
                if teams_df.loc[teams_df['name'] == dev, 'stack'].values[0] == task_stack
            ]

            if compatible_devs:
                if random.random() < exploitation_prob_adap:
                    assigned_dev = min(compatible_devs, key=lambda d: dev_hours[d])
                else:
                    other_devs = [d for d in compatible_devs if d != chromosome[i]]
                    if not other_devs:
                        continue
                    assigned_dev = random.choice(other_devs)

                new_hours = dev_hours[assigned_dev] + task_hours
                level = teams_df.loc[teams_df['name'] == assigned_dev, 'level'].values[0]
                max_allowed = level_rules[level]['max_daily_hours'] * sprint_days

                if new_hours <= max_allowed:
                    dev_hours[assigned_dev] += task_hours
                    dev_hours[chromosome[i]] -= task_hours
                    chromosome[i] = assigned_dev

    return chromosome


def validate_chromosome(chromosome, tasks_df, teams_df):
    for i, dev in enumerate(chromosome):
        task_stack = tasks_df.iloc[i]['stack']
        dev_stack = team_info[dev]['stack']
        if dev_stack != task_stack:
            return False

    return True

def print_dev_load(chromosome, tasks_df):
    dev_hours = defaultdict(float)

    for task_idx, dev in enumerate(chromosome):
        dev_hours[dev] += tasks_df.iloc[task_idx]['estimated_hours']

    dev_hours = sorted(dev_hours.items(), key=lambda x: x[0], reverse=False)
    print("Carga horária por desenvolvedor:")
    for dev, hours in dev_hours:
        dev_info = teams_df[teams_df['name'] == dev].iloc[0]
        tasks = filter_tasks_per_dev(chromosome, dev)
        print(f"{dev}: {hours:.2f}h ({tasks} tasks) - {dev_info['level']} ({dev_info['stack']})")

def check_compatibility(chromosome, tasks_df, teams_df):
    incompatibilities = []
    for i, dev in enumerate(chromosome):
        task_stack = tasks_df.iloc[i]['stack']
        dev_stack = teams_df.loc[teams_df['name'] == dev, 'stack'].values[0]
        if dev_stack != task_stack:
            incompatibilities.append((i, dev, task_stack, dev_stack))
    if incompatibilities:
        print("Incompatibilidades encontradas:")
        for task_idx, dev, task_stack, dev_stack in incompatibilities:
            print(f"Task {task_idx} (stack {task_stack}) -> Dev {dev} (stack {dev_stack})")
    else:
        print("Todas as tasks estão alocadas a devs compatíveis!")


def tasks_per_dev(chromosome):
    count = Counter(chromosome)
    print("Número de tasks por dev:")
    for dev, num in count.items():
        print(f"{dev}: {num}")


def filter_tasks_per_dev(chromosome, dev):
    count = Counter(chromosome)
    return count.get(dev, 0)

def local_search_incremental(chromosome, tasks_df, teams_df, developers, max_iterations=3, max_swaps_per_iter=50):
    best_chr = chromosome
    best_fit = fitness(chromosome, tasks_df, teams_df)
    iteration = 0
    improved = True
    n_tasks = len(chromosome)

    # Calcula cargas iniciais uma vez só
    dev_hours = {dev:0 for dev in developers}
    for idx, dev in enumerate(chromosome):
        dev_hours[dev] += tasks_df.iloc[idx]['estimated_hours']

    while improved and iteration < max_iterations:
        improved = False
        swaps_tested = 0

        # Amostra aleatória de pares (rapidamente explora espaço sem rodar todos)
        all_pairs = [(i, j) for i in range(n_tasks) for j in range(i+1, n_tasks)]
        random.shuffle(all_pairs)

        for i, j in all_pairs:
            if swaps_tested >= max_swaps_per_iter:
                break
            swaps_tested += 1

            dev_i = best_chr[i]
            dev_j = best_chr[j]
            task_i = tasks_df.iloc[i]['estimated_hours']
            task_j = tasks_df.iloc[j]['estimated_hours']

            # Compatibilidade para swap
            if (team_info[dev_j]['stack'] == tasks_df.iloc[i]['stack'] and
                team_info[dev_i]['stack'] == tasks_df.iloc[j]['stack']):

                # Atualiza as cargas apenas nos devs do swap
                new_dev_hours = dev_hours.copy()
                new_dev_hours[dev_i] += task_j - task_i
                new_dev_hours[dev_j] += task_i - task_j

                max_hours_i = level_rules[team_info[dev_i]['level']]['max_daily_hours'] * sprint_days
                max_hours_j = level_rules[team_info[dev_j]['level']]['max_daily_hours'] * sprint_days

                if new_dev_hours[dev_i] <= max_hours_i and new_dev_hours[dev_j] <= max_hours_j:
                    new_chr = best_chr.copy()
                    new_chr[i] = dev_j
                    new_chr[j] = dev_i

                    new_fit = fitness(new_chr, tasks_df, teams_df)
                    if new_fit < best_fit:
                        best_chr = new_chr
                        best_fit = new_fit
                        dev_hours = new_dev_hours  # só atualiza se swap foi bom
                        improved = True
                        break
        iteration += 1
    return best_chr


population = generate_population(population_size, tasks_df, developers, teams_df)

print(f"População inicial gerada com {population_size} soluções.")
print("Exemplo de cromossomo da população:")
print(population[0])

for generation in range(num_generations):
    # Avaliar fitness de cada indivíduo
    fitness_values = [fitness(individual, tasks_df, teams_df) for individual in population]

    best_fitness = min(fitness_values)
    avg_fitness = sum(fitness_values) / len(fitness_values)
    best_fitness_history.append(best_fitness)
    avg_fitness_history.append(avg_fitness)

    print(f"Geração {generation + 1} - Melhor fitness: {best_fitness:.2f} - Fitness médio: {avg_fitness:.2f}")

    if best_fitness < best_fitness_overall:
        if mutation_rate != base_mutation_rate:
            print(f"Resetando mutação")
            mutation_rate = base_mutation_rate

        no_improve = 0

        best_fitness_overall = best_fitness
        best_solution_overall = population[np.argmin(fitness_values)]
    else:
        no_improve += 1

        if no_improve >= no_improvement_threshold:
            inc_mutation_rate = min(mutation_rate + 0.05, max_mutation_rate)

            if inc_mutation_rate != mutation_rate:
                mutation_rate = inc_mutation_rate
                print(f"Aumentando mutação para: {mutation_rate}")

    if no_improve >= max_no_improve:
        print("Parando por estagnação!")
        break

    new_population = []

    # Elite
    elite_size = 3  # Escolhe só o top 3
    sorted_pop = [x for _, x in sorted(zip(fitness_values, population), key=lambda pair: pair[0])]
    elite = sorted_pop[:elite_size]

    # Aplicação de busca local só nos top 3 elite
    new_population.extend([local_search_incremental(ind, tasks_df, teams_df, developers) for ind in elite])

    # validar alterar p 30 a 70 gerações
    if generation % 30 == 0:
        for _ in range(population_size // 10):
            new_population.append(generate_random_chromosome_balanced(tasks_df, developers, teams_df))

    # Criação de nova população até completar o tamanho
    while len(new_population) < population_size:
        # Seleção dos pais via torneio
        parent1 = tournament_selection(population, fitness_values)
        parent2 = tournament_selection(population, fitness_values)

        attempts_tournament = 0
        while parent1 == parent2 and attempts_tournament < max_attempts_tournament:
            parent2 = tournament_selection(population, fitness_values)
            attempts_tournament += 1

        if parent1 == parent2:
            # fallback simples: escolhe qualquer um diferente do parent1
            candidates = [ind for ind in population if ind != parent1]
            parent2 = random.choice(candidates)

        # Gerar filho pelo crossover e corrigir incompatibilidades
        if random.random() < 0.5:
            child = two_point_crossover(parent1, parent2)
        else:
            child = uniform_crossover(parent1, parent2)

        child = correct_incompatibilities(child, tasks_df, developers, teams_df)

        # Mutação
        child = mutate_balanced(child, developers, teams_df, tasks_df, mutation_rate)
        new_population.append(child)

    population = new_population


print("Melhor solução encontrada:")
print(best_solution_overall)

# Análises complementares
print_dev_load(best_solution_overall, tasks_df)
check_compatibility(best_solution_overall, tasks_df, teams_df)

plt.plot(best_fitness_history, label='Melhor fitness')
plt.plot(avg_fitness_history, label='Fitness médio')
plt.xlabel('Geração')
plt.ylabel('Fitness')
plt.title('Evolução do Fitness')
plt.legend()
plt.grid(True)
plt.show()

def get_dev_tasks(chromosome, tasks_df):
    dev_task_map = defaultdict(list)
    for task_idx, dev in enumerate(chromosome):
        task_info = tasks_df.iloc[task_idx]
        dev_task_map[dev].append({
            "task_idx": task_idx,
            "stack": task_info['stack'],
            "priority": task_info['priority'],
            "estimated_hours": task_info['estimated_hours'],
            "task_name": task_info.get('name', f"Task_{task_idx+1}")
        })
    return dev_task_map

def print_dev_task_details(chromosome, tasks_df):
    dev_tasks = get_dev_tasks(chromosome, tasks_df)
    for dev, tasks in dev_tasks.items():
        total_hours = sum(t['estimated_hours'] for t in tasks)
        print(f"\n{dev}: {total_hours:.2f}h, {len(tasks)} tasks")
        for t in tasks:
            print(f"  - {t['task_name']}: {t['estimated_hours']}h [{t['stack']}/{t['priority']}]")


print_dev_task_details(best_solution_overall, tasks_df)

import matplotlib.pyplot as plt
dev_hours = defaultdict(float)
for task_idx, dev in enumerate(best_solution_overall):
    dev_hours[dev] += tasks_df.iloc[task_idx]['estimated_hours']
plt.bar(dev_hours.keys(), dev_hours.values())
plt.xticks(rotation=90)
plt.ylabel('Horas Totais')
plt.title('Horas Alocadas por Dev')
plt.show()
# Out:
# População inicial gerada com 198 soluções.
# Exemplo de cromossomo da população:
# ['F_Dev1', 'A_Dev8', 'A_Dev1', 'C_Dev1', 'B_Dev1', 'B_Dev1', 'B_Dev2', 'F_Dev1', 'A_Dev8', 'F_Dev3', 'A_Dev6', 'A_Dev3', 'B_Dev4', 'B_Dev4', 'A_Dev5', 'B_Dev4', 'B_Dev7', 'E_Dev3', 'D_Dev1', 'B_Dev4', 'E_Dev3', 'B_Dev6', 'F_Dev1', 'F_Dev1', 'E_Dev2', 'E_Dev3', 'D_Dev4', 'B_Dev7', 'E_Dev1', 'D_Dev1', 'C_Dev1', 'A_Dev1', 'B_Dev1', 'D_Dev4', 'C_Dev3', 'C_Dev1', 'B_Dev2', 'B_Dev6', 'C_Dev3', 'A_Dev8', 'B_Dev4', 'D_Dev3', 'B_Dev4', 'C_Dev6', 'C_Dev5', 'C_Dev1', 'A_Dev2', 'E_Dev1', 'F_Dev3', 'A_Dev8', 'D_Dev5', 'A_Dev6', 'D_Dev1', 'C_Dev2', 'B_Dev5', 'E_Dev3', 'B_Dev6', 'F_Dev1', 'A_Dev3', 'A_Dev3', 'B_Dev7', 'C_Dev2', 'A_Dev6', 'B_Dev7', 'B_Dev4', 'D_Dev5', 'C_Dev1', 'D_Dev5', 'C_Dev5', 'B_Dev3', 'C_Dev5', 'D_Dev3', 'A_Dev5', 'F_Dev1', 'D_Dev3', 'E_Dev2', 'A_Dev6', 'B_Dev3', 'A_Dev5', 'B_Dev1', 'E_Dev1', 'D_Dev3', 'A_Dev3', 'D_Dev1', 'E_Dev2', 'A_Dev5', 'F_Dev1', 'C_Dev3', 'A_Dev4', 'B_Dev1', 'A_Dev2', 'C_Dev4', 'D_Dev2', 'C_Dev1', 'A_Dev6', 'B_Dev6', 'C_Dev3', 'B_Dev6', 'E_Dev4']
# Geração 1 - Melhor fitness: 2084.46 - Fitness médio: 3590.44
# Geração 2 - Melhor fitness: 1900.46 - Fitness médio: 3222.24
# Geração 3 - Melhor fitness: 1580.09 - Fitness médio: 2619.84
# Geração 4 - Melhor fitness: 1505.39 - Fitness médio: 2427.82
# Geração 5 - Melhor fitness: 1444.07 - Fitness médio: 2365.32
# Geração 6 - Melhor fitness: 1355.47 - Fitness médio: 2311.39
# Geração 7 - Melhor fitness: 1355.47 - Fitness médio: 2228.77
# Geração 8 - Melhor fitness: 1302.50 - Fitness médio: 2196.06
# Geração 9 - Melhor fitness: 1300.93 - Fitness médio: 2165.73
# Geração 10 - Melhor fitness: 1292.48 - Fitness médio: 2135.79
# Geração 11 - Melhor fitness: 1234.11 - Fitness médio: 1692.01
# Geração 12 - Melhor fitness: 1234.09 - Fitness médio: 1520.08
# Geração 13 - Melhor fitness: 1183.00 - Fitness médio: 1492.89
# Geração 14 - Melhor fitness: 1158.89 - Fitness médio: 1503.09
# Geração 15 - Melhor fitness: 1157.57 - Fitness médio: 1488.01
# Geração 16 - Melhor fitness: 1134.89 - Fitness médio: 1501.47
# Geração 17 - Melhor fitness: 1133.70 - Fitness médio: 1551.75
# Geração 18 - Melhor fitness: 1064.05 - Fitness médio: 1473.02
# Geração 19 - Melhor fitness: 1051.76 - Fitness médio: 1388.15
# Geração 20 - Melhor fitness: 1051.66 - Fitness médio: 1280.43
# Geração 21 - Melhor fitness: 982.83 - Fitness médio: 1164.16
# Geração 22 - Melhor fitness: 970.63 - Fitness médio: 1165.98
# Geração 23 - Melhor fitness: 970.37 - Fitness médio: 1114.52
# Geração 24 - Melhor fitness: 968.16 - Fitness médio: 1055.39
# Geração 25 - Melhor fitness: 893.15 - Fitness médio: 1005.34
# Geração 26 - Melhor fitness: 892.81 - Fitness médio: 995.17
# Geração 27 - Melhor fitness: 892.81 - Fitness médio: 1000.23
# Geração 28 - Melhor fitness: 890.71 - Fitness médio: 1012.79
# Geração 29 - Melhor fitness: 890.50 - Fitness médio: 998.67
# Geração 30 - Melhor fitness: 890.40 - Fitness médio: 1000.66
# Geração 31 - Melhor fitness: 890.40 - Fitness médio: 1051.14
# Geração 32 - Melhor fitness: 890.32 - Fitness médio: 1233.88
# Geração 33 - Melhor fitness: 888.14 - Fitness médio: 1051.18
# Geração 34 - Melhor fitness: 888.14 - Fitness médio: 1126.13
# Geração 35 - Melhor fitness: 888.14 - Fitness médio: 1127.24
# Geração 36 - Melhor fitness: 887.94 - Fitness médio: 1157.80
# Geração 37 - Melhor fitness: 887.41 - Fitness médio: 1092.29
# Geração 38 - Melhor fitness: 887.41 - Fitness médio: 1069.64
# Geração 39 - Melhor fitness: 887.41 - Fitness médio: 1134.65
# Geração 40 - Melhor fitness: 887.33 - Fitness médio: 1148.01
# Geração 41 - Melhor fitness: 887.33 - Fitness médio: 1138.57
# Geração 42 - Melhor fitness: 887.05 - Fitness médio: 1134.02
# Geração 43 - Melhor fitness: 887.05 - Fitness médio: 1109.84
# Geração 44 - Melhor fitness: 887.05 - Fitness médio: 1028.12
# Geração 45 - Melhor fitness: 887.05 - Fitness médio: 1130.59
# Geração 46 - Melhor fitness: 887.05 - Fitness médio: 1131.38
# Geração 47 - Melhor fitness: 886.99 - Fitness médio: 1140.60
# Geração 48 - Melhor fitness: 886.99 - Fitness médio: 1312.55
# Geração 49 - Melhor fitness: 886.99 - Fitness médio: 1195.71
# Geração 50 - Melhor fitness: 886.93 - Fitness médio: 1237.95
# Geração 51 - Melhor fitness: 886.93 - Fitness médio: 1136.67
# Geração 52 - Melhor fitness: 886.89 - Fitness médio: 1180.58
# Geração 53 - Melhor fitness: 886.87 - Fitness médio: 1110.98
# Geração 54 - Melhor fitness: 886.87 - Fitness médio: 1272.90
# Geração 55 - Melhor fitness: 886.87 - Fitness médio: 1184.48
# Geração 56 - Melhor fitness: 886.67 - Fitness médio: 1217.61
# Geração 57 - Melhor fitness: 886.67 - Fitness médio: 1335.43
# Geração 58 - Melhor fitness: 886.67 - Fitness médio: 1300.26
# Geração 59 - Melhor fitness: 886.67 - Fitness médio: 1347.74
# Geração 60 - Melhor fitness: 886.67 - Fitness médio: 1284.54
# Geração 61 - Melhor fitness: 886.67 - Fitness médio: 1314.32
# Geração 62 - Melhor fitness: 886.67 - Fitness médio: 1296.78
# Geração 63 - Melhor fitness: 886.67 - Fitness médio: 1159.20
# Aumentando mutação para: 0.1
# Geração 64 - Melhor fitness: 886.67 - Fitness médio: 1070.85
# Aumentando mutação para: 0.15000000000000002
# Geração 65 - Melhor fitness: 886.67 - Fitness médio: 1101.61
# Aumentando mutação para: 0.2
# Geração 66 - Melhor fitness: 886.67 - Fitness médio: 1163.69
# Resetando mutação
# Geração 67 - Melhor fitness: 886.59 - Fitness médio: 1105.84
# Geração 68 - Melhor fitness: 886.59 - Fitness médio: 1372.21
# Geração 69 - Melhor fitness: 886.59 - Fitness médio: 1303.39
# Geração 70 - Melhor fitness: 886.59 - Fitness médio: 1420.04
# Geração 71 - Melhor fitness: 886.59 - Fitness médio: 1332.19
# Geração 72 - Melhor fitness: 886.59 - Fitness médio: 1425.97
# Aumentando mutação para: 0.1
# Geração 73 - Melhor fitness: 886.57 - Fitness médio: 1376.13
# Resetando mutação
# Geração 74 - Melhor fitness: 886.57 - Fitness médio: 1053.14
# Geração 75 - Melhor fitness: 886.54 - Fitness médio: 1019.10
# Geração 76 - Melhor fitness: 886.46 - Fitness médio: 963.82
# Geração 77 - Melhor fitness: 886.46 - Fitness médio: 947.52
# Geração 78 - Melhor fitness: 886.42 - Fitness médio: 903.11
# Geração 79 - Melhor fitness: 886.42 - Fitness médio: 906.19
# Geração 80 - Melhor fitness: 886.42 - Fitness médio: 901.72
# Geração 81 - Melhor fitness: 886.42 - Fitness médio: 901.35
# Geração 82 - Melhor fitness: 886.42 - Fitness médio: 910.27
# Geração 83 - Melhor fitness: 886.40 - Fitness médio: 916.15
# Geração 84 - Melhor fitness: 886.40 - Fitness médio: 938.95
# Geração 85 - Melhor fitness: 886.40 - Fitness médio: 1007.48
# Geração 86 - Melhor fitness: 886.36 - Fitness médio: 1028.53
# Geração 87 - Melhor fitness: 886.36 - Fitness médio: 985.26
# Geração 88 - Melhor fitness: 886.36 - Fitness médio: 943.21
# Geração 89 - Melhor fitness: 886.36 - Fitness médio: 936.20
# Geração 90 - Melhor fitness: 849.70 - Fitness médio: 930.24
# Geração 91 - Melhor fitness: 849.70 - Fitness médio: 901.97
# Geração 92 - Melhor fitness: 849.70 - Fitness médio: 1086.72
# Geração 93 - Melhor fitness: 849.70 - Fitness médio: 873.34
# Geração 94 - Melhor fitness: 849.70 - Fitness médio: 855.82
# Geração 95 - Melhor fitness: 849.70 - Fitness médio: 861.46
# Geração 96 - Melhor fitness: 849.70 - Fitness médio: 876.07
# Geração 97 - Melhor fitness: 849.70 - Fitness médio: 897.98
# Geração 98 - Melhor fitness: 849.70 - Fitness médio: 928.11
# Geração 99 - Melhor fitness: 849.70 - Fitness médio: 1036.40
# Geração 100 - Melhor fitness: 849.70 - Fitness médio: 1048.45
# Geração 101 - Melhor fitness: 849.70 - Fitness médio: 971.83
# Geração 102 - Melhor fitness: 849.70 - Fitness médio: 930.81
# Geração 103 - Melhor fitness: 849.70 - Fitness médio: 983.75
# Geração 104 - Melhor fitness: 849.70 - Fitness médio: 1008.52
# Aumentando mutação para: 0.1
# Geração 105 - Melhor fitness: 849.70 - Fitness médio: 1014.09
# Aumentando mutação para: 0.15000000000000002
# Geração 106 - Melhor fitness: 849.70 - Fitness médio: 1022.09
# Aumentando mutação para: 0.2
# Geração 107 - Melhor fitness: 849.70 - Fitness médio: 994.88
# Aumentando mutação para: 0.25
# Geração 108 - Melhor fitness: 849.70 - Fitness médio: 984.58
# Aumentando mutação para: 0.3
# Geração 109 - Melhor fitness: 849.70 - Fitness médio: 942.31
# Aumentando mutação para: 0.35
# Geração 110 - Melhor fitness: 849.70 - Fitness médio: 980.70
# Aumentando mutação para: 0.39999999999999997
# Geração 111 - Melhor fitness: 849.70 - Fitness médio: 970.94
# Aumentando mutação para: 0.44999999999999996
# Geração 112 - Melhor fitness: 849.68 - Fitness médio: 928.68
# Resetando mutação
# Geração 113 - Melhor fitness: 849.68 - Fitness médio: 986.61
# Geração 114 - Melhor fitness: 849.68 - Fitness médio: 962.80
# Geração 115 - Melhor fitness: 849.68 - Fitness médio: 968.64
# Geração 116 - Melhor fitness: 849.68 - Fitness médio: 921.88
# Geração 117 - Melhor fitness: 849.68 - Fitness médio: 1000.45
# Geração 118 - Melhor fitness: 849.68 - Fitness médio: 967.95
# Geração 119 - Melhor fitness: 849.68 - Fitness médio: 940.12
# Geração 120 - Melhor fitness: 849.68 - Fitness médio: 879.54
# Geração 121 - Melhor fitness: 849.68 - Fitness médio: 878.57
# Geração 122 - Melhor fitness: 849.60 - Fitness médio: 1079.99
# Geração 123 - Melhor fitness: 849.60 - Fitness médio: 874.68
# Geração 124 - Melhor fitness: 849.60 - Fitness médio: 873.05
# Geração 125 - Melhor fitness: 849.60 - Fitness médio: 890.07
# Geração 126 - Melhor fitness: 849.60 - Fitness médio: 877.66
# Geração 127 - Melhor fitness: 849.60 - Fitness médio: 878.76
# Geração 128 - Melhor fitness: 849.60 - Fitness médio: 883.12
# Geração 129 - Melhor fitness: 849.60 - Fitness médio: 892.22
# Aumentando mutação para: 0.1
# Geração 130 - Melhor fitness: 845.30 - Fitness médio: 886.71
# Resetando mutação
# Geração 131 - Melhor fitness: 837.23 - Fitness médio: 881.35
# Geração 132 - Melhor fitness: 835.21 - Fitness médio: 866.43
# Geração 133 - Melhor fitness: 824.96 - Fitness médio: 846.04
# Geração 134 - Melhor fitness: 822.95 - Fitness médio: 861.45
# Geração 135 - Melhor fitness: 822.95 - Fitness médio: 867.36
# Geração 136 - Melhor fitness: 822.95 - Fitness médio: 862.57
# Geração 137 - Melhor fitness: 822.95 - Fitness médio: 847.06
# Geração 138 - Melhor fitness: 822.95 - Fitness médio: 838.73
# Geração 139 - Melhor fitness: 822.95 - Fitness médio: 841.59
# Aumentando mutação para: 0.1
# Geração 140 - Melhor fitness: 822.95 - Fitness médio: 843.19
# Aumentando mutação para: 0.15000000000000002
# Geração 141 - Melhor fitness: 822.95 - Fitness médio: 848.69
# Aumentando mutação para: 0.2
# Geração 142 - Melhor fitness: 822.95 - Fitness médio: 844.22
# Aumentando mutação para: 0.25
# Geração 143 - Melhor fitness: 822.95 - Fitness médio: 847.61
# Aumentando mutação para: 0.3
# Geração 144 - Melhor fitness: 822.95 - Fitness médio: 844.44
# Aumentando mutação para: 0.35
# Geração 145 - Melhor fitness: 822.95 - Fitness médio: 842.94
# Aumentando mutação para: 0.39999999999999997
# Geração 146 - Melhor fitness: 822.95 - Fitness médio: 841.83
# Aumentando mutação para: 0.44999999999999996
# Geração 147 - Melhor fitness: 822.95 - Fitness médio: 843.13
# Aumentando mutação para: 0.49999999999999994
# Geração 148 - Melhor fitness: 822.95 - Fitness médio: 846.49
# Aumentando mutação para: 0.5
# Geração 149 - Melhor fitness: 822.95 - Fitness médio: 849.06
# Geração 150 - Melhor fitness: 822.95 - Fitness médio: 848.21
# Geração 151 - Melhor fitness: 822.84 - Fitness médio: 842.39
# Resetando mutação
# Geração 152 - Melhor fitness: 822.84 - Fitness médio: 1065.30
# Geração 153 - Melhor fitness: 822.84 - Fitness médio: 872.53
# Geração 154 - Melhor fitness: 822.84 - Fitness médio: 872.43
# Geração 155 - Melhor fitness: 822.75 - Fitness médio: 872.22
# Geração 156 - Melhor fitness: 822.75 - Fitness médio: 877.77
# Geração 157 - Melhor fitness: 822.75 - Fitness médio: 883.13
# Geração 158 - Melhor fitness: 822.75 - Fitness médio: 866.67
# Geração 159 - Melhor fitness: 822.75 - Fitness médio: 837.71
# Geração 160 - Melhor fitness: 822.75 - Fitness médio: 850.89
# Aumentando mutação para: 0.1
# Geração 161 - Melhor fitness: 822.75 - Fitness médio: 871.22
# Aumentando mutação para: 0.15000000000000002
# Geração 162 - Melhor fitness: 822.75 - Fitness médio: 881.82
# Aumentando mutação para: 0.2
# Geração 163 - Melhor fitness: 822.75 - Fitness médio: 859.10
# Aumentando mutação para: 0.25
# Geração 164 - Melhor fitness: 797.46 - Fitness médio: 843.36
# Resetando mutação
# Geração 165 - Melhor fitness: 797.46 - Fitness médio: 872.24
# Geração 166 - Melhor fitness: 797.46 - Fitness médio: 879.57
# Geração 167 - Melhor fitness: 797.46 - Fitness médio: 889.41
# Geração 168 - Melhor fitness: 797.46 - Fitness médio: 895.27
# Geração 169 - Melhor fitness: 797.46 - Fitness médio: 882.80
# Aumentando mutação para: 0.1
# Geração 170 - Melhor fitness: 797.46 - Fitness médio: 863.70
# Aumentando mutação para: 0.15000000000000002
# Geração 171 - Melhor fitness: 797.46 - Fitness médio: 871.09
# Aumentando mutação para: 0.2
# Geração 172 - Melhor fitness: 797.46 - Fitness médio: 862.04
# Aumentando mutação para: 0.25
# Geração 173 - Melhor fitness: 797.46 - Fitness médio: 862.54
# Aumentando mutação para: 0.3
# Geração 174 - Melhor fitness: 797.46 - Fitness médio: 853.56
# Aumentando mutação para: 0.35
# Geração 175 - Melhor fitness: 797.46 - Fitness médio: 854.39
# Aumentando mutação para: 0.39999999999999997
# Geração 176 - Melhor fitness: 797.46 - Fitness médio: 855.26
# Aumentando mutação para: 0.44999999999999996
# Geração 177 - Melhor fitness: 797.46 - Fitness médio: 872.38
# Aumentando mutação para: 0.49999999999999994
# Geração 178 - Melhor fitness: 797.46 - Fitness médio: 863.60
# Aumentando mutação para: 0.5
# Geração 179 - Melhor fitness: 797.46 - Fitness médio: 858.48
# Geração 180 - Melhor fitness: 797.46 - Fitness médio: 864.18
# Geração 181 - Melhor fitness: 797.46 - Fitness médio: 868.33
# Geração 182 - Melhor fitness: 797.46 - Fitness médio: 1071.22
# Geração 183 - Melhor fitness: 797.46 - Fitness médio: 874.96
# Geração 184 - Melhor fitness: 797.46 - Fitness médio: 856.84
# Parando por estagnação!
# Melhor solução encontrada:
# ['A_Dev3', 'C_Dev4', 'A_Dev5', 'A_Dev4', 'E_Dev3', 'A_Dev7', 'A_Dev8', 'C_Dev6', 'A_Dev8', 'C_Dev5', 'D_Dev3', 'A_Dev5', 'A_Dev3', 'F_Dev1', 'B_Dev4', 'B_Dev2', 'D_Dev3', 'B_Dev5', 'A_Dev3', 'C_Dev4', 'D_Dev1', 'E_Dev1', 'A_Dev7', 'A_Dev5', 'A_Dev3', 'D_Dev5', 'B_Dev4', 'F_Dev2', 'A_Dev7', 'B_Dev5', 'E_Dev3', 'D_Dev1', 'A_Dev2', 'E_Dev2', 'B_Dev1', 'D_Dev1', 'A_Dev2', 'E_Dev2', 'D_Dev5', 'C_Dev6', 'C_Dev2', 'A_Dev4', 'C_Dev6', 'C_Dev3', 'A_Dev4', 'B_Dev4', 'C_Dev3', 'F_Dev1', 'D_Dev1', 'C_Dev1', 'B_Dev1', 'B_Dev4', 'D_Dev2', 'C_Dev4', 'C_Dev6', 'A_Dev8', 'A_Dev4', 'A_Dev6', 'C_Dev4', 'A_Dev2', 'A_Dev4', 'F_Dev2', 'E_Dev3', 'A_Dev6', 'D_Dev5', 'B_Dev3', 'D_Dev5', 'B_Dev2', 'F_Dev1', 'C_Dev5', 'F_Dev3', 'A_Dev8', 'C_Dev2', 'D_Dev4', 'A_Dev1', 'A_Dev1', 'F_Dev3', 'E_Dev4', 'B_Dev2', 'B_Dev3', 'B_Dev3', 'F_Dev3', 'D_Dev4', 'B_Dev6', 'B_Dev7', 'B_Dev6', 'A_Dev2', 'B_Dev7', 'A_Dev1', 'D_Dev2', 'B_Dev7', 'C_Dev1', 'E_Dev4', 'A_Dev6', 'C_Dev5', 'D_Dev2', 'D_Dev4', 'E_Dev1', 'B_Dev6']
# Carga horária por desenvolvedor:
# A_Dev1: 50.00h (3 tasks) - Intern (BE)
# A_Dev2: 70.00h (4 tasks) - Junior (BE)
# A_Dev3: 72.00h (4 tasks) - Mid-level (DB)
# A_Dev4: 69.00h (5 tasks) - Mid-level (FE)
# A_Dev5: 93.00h (3 tasks) - Mid-level (MO)
# A_Dev6: 69.00h (3 tasks) - Senior (BE)
# A_Dev7: 89.00h (3 tasks) - Senior (DS)
# A_Dev8: 60.00h (4 tasks) - Specialist (BE)
# B_Dev1: 50.00h (2 tasks) - Intern (FE)
# B_Dev2: 70.00h (3 tasks) - Junior (BE)
# B_Dev3: 70.00h (3 tasks) - Mid-level (BE)
# B_Dev4: 65.00h (4 tasks) - Mid-level (DE)
# B_Dev5: 52.00h (2 tasks) - Mid-level (MO)
# B_Dev6: 70.00h (3 tasks) - Senior (BE)
# B_Dev7: 69.00h (3 tasks) - Senior (BE)
# C_Dev1: 70.00h (2 tasks) - Junior (BE)
# C_Dev2: 67.00h (2 tasks) - Mid-level (BE)
# C_Dev3: 69.00h (2 tasks) - Mid-level (BE)
# C_Dev4: 69.00h (4 tasks) - Mid-level (FE)
# C_Dev5: 70.00h (3 tasks) - Senior (BE)
# C_Dev6: 99.00h (4 tasks) - Senior (DE)
# D_Dev1: 70.00h (4 tasks) - Junior (DE)
# D_Dev2: 69.00h (3 tasks) - Mid-level (BE)
# D_Dev3: 70.00h (2 tasks) - Mid-level (DS)
# D_Dev4: 69.00h (3 tasks) - Senior (BE)
# D_Dev5: 69.00h (4 tasks) - Senior (FE)
# E_Dev1: 70.00h (2 tasks) - Mid-level (BE)
# E_Dev2: 64.00h (2 tasks) - Senior (DS)
# E_Dev3: 91.00h (3 tasks) - Senior (FE)
# E_Dev4: 70.00h (2 tasks) - Specialist (BE)
# F_Dev1: 70.00h (3 tasks) - Mid-level (FE)
# F_Dev2: 70.00h (2 tasks) - Senior (BE)
# F_Dev3: 95.00h (3 tasks) - Specialist (BE)
# Todas as tasks estão alocadas a devs compatíveis!
# A_Dev3: 72.00h, 4 tasks
#   - Task_1: 7h [DB/Critical]
#   - Task_13: 6h [DB/Medium]
#   - Task_19: 27h [DB/Low]
#   - Task_25: 32h [DB/Medium]
#
# C_Dev4: 69.00h, 4 tasks
#   - Task_2: 5h [FE/Disaster]
#   - Task_20: 26h [FE/High]
#   - Task_54: 14h [FE/High]
#   - Task_59: 24h [FE/Low]
#
# A_Dev5: 93.00h, 3 tasks
#   - Task_3: 22h [MO/High]
#   - Task_12: 49h [MO/Low]
#   - Task_24: 22h [MO/Low]
#
# A_Dev4: 69.00h, 5 tasks
#   - Task_4: 6h [FE/Low]
#   - Task_42: 25h [FE/Low]
#   - Task_45: 11h [FE/Critical]
#   - Task_57: 22h [FE/High]
#   - Task_61: 5h [FE/Critical]
#
# E_Dev3: 91.00h, 3 tasks
#   - Task_5: 31h [FE/Medium]
#   - Task_31: 27h [FE/Low]
#   - Task_63: 33h [FE/High]
#
# A_Dev7: 89.00h, 3 tasks
#   - Task_6: 31h [DS/Low]
#   - Task_23: 29h [DS/High]
#   - Task_29: 29h [DS/Low]
#
# A_Dev8: 60.00h, 4 tasks
#   - Task_7: 18h [BE/High]
#   - Task_9: 5h [BE/Low]
#   - Task_56: 17h [BE/Critical]
#   - Task_72: 20h [BE/Medium]
#
# C_Dev6: 99.00h, 4 tasks
#   - Task_8: 16h [DE/Low]
#   - Task_40: 26h [DE/High]
#   - Task_43: 31h [DE/Medium]
#   - Task_55: 26h [DE/Critical]
#
# C_Dev5: 70.00h, 3 tasks
#   - Task_10: 6h [BE/Low]
#   - Task_70: 37h [BE/Low]
#   - Task_95: 27h [BE/Medium]
#
# D_Dev3: 70.00h, 2 tasks
#   - Task_11: 33h [DS/Low]
#   - Task_17: 37h [DS/Low]
#
# F_Dev1: 70.00h, 3 tasks
#   - Task_14: 22h [FE/Low]
#   - Task_48: 22h [FE/Medium]
#   - Task_69: 26h [FE/Medium]
#
# B_Dev4: 65.00h, 4 tasks
#   - Task_15: 33h [DE/High]
#   - Task_27: 2h [DE/Critical]
#   - Task_46: 10h [DE/High]
#   - Task_52: 20h [DE/High]
#
# B_Dev2: 70.00h, 3 tasks
#   - Task_16: 12h [BE/Low]
#   - Task_68: 31h [BE/Medium]
#   - Task_79: 27h [BE/High]
#
# B_Dev5: 52.00h, 2 tasks
#   - Task_18: 19h [MO/Medium]
#   - Task_30: 33h [MO/Low]
#
# D_Dev1: 70.00h, 4 tasks
#   - Task_21: 16h [DE/High]
#   - Task_32: 17h [DE/Medium]
#   - Task_36: 15h [DE/High]
#   - Task_49: 22h [DE/High]
#
# E_Dev1: 70.00h, 2 tasks
#   - Task_22: 34h [BE/Medium]
#   - Task_98: 36h [BE/Critical]
#
# D_Dev5: 69.00h, 4 tasks
#   - Task_26: 34h [FE/Medium]
#   - Task_39: 22h [FE/Critical]
#   - Task_65: 8h [FE/Medium]
#   - Task_67: 5h [FE/Low]
#
# F_Dev2: 70.00h, 2 tasks
#   - Task_28: 37h [BE/Low]
#   - Task_62: 33h [BE/Low]
#
# A_Dev2: 70.00h, 4 tasks
#   - Task_33: 32h [BE/Medium]
#   - Task_37: 17h [BE/Medium]
#   - Task_60: 14h [BE/High]
#   - Task_87: 7h [BE/Medium]
#
# E_Dev2: 64.00h, 2 tasks
#   - Task_34: 22h [DS/Low]
#   - Task_38: 42h [DS/High]
#
# B_Dev1: 50.00h, 2 tasks
#   - Task_35: 25h [FE/High]
#   - Task_51: 25h [FE/High]
#
# C_Dev2: 67.00h, 2 tasks
#   - Task_41: 29h [BE/Medium]
#   - Task_73: 38h [BE/High]
#
# C_Dev3: 69.00h, 2 tasks
#   - Task_44: 38h [BE/Low]
#   - Task_47: 31h [BE/Critical]
#
# C_Dev1: 70.00h, 2 tasks
#   - Task_50: 39h [BE/High]
#   - Task_92: 31h [BE/High]
#
# D_Dev2: 69.00h, 3 tasks
#   - Task_53: 27h [BE/High]
#   - Task_90: 11h [BE/Medium]
#   - Task_96: 31h [BE/Medium]
#
# A_Dev6: 69.00h, 3 tasks
#   - Task_58: 24h [BE/High]
#   - Task_64: 8h [BE/Disaster]
#   - Task_94: 37h [BE/Disaster]
#
# B_Dev3: 70.00h, 3 tasks
#   - Task_66: 29h [BE/High]
#   - Task_80: 28h [BE/Medium]
#   - Task_81: 13h [BE/High]
#
# F_Dev3: 95.00h, 3 tasks
#   - Task_71: 20h [BE/High]
#   - Task_77: 35h [BE/Low]
#   - Task_82: 40h [BE/Medium]
#
# D_Dev4: 69.00h, 3 tasks
#   - Task_74: 24h [BE/Low]
#   - Task_83: 25h [BE/High]
#   - Task_97: 20h [BE/High]
#
# A_Dev1: 50.00h, 3 tasks
#   - Task_75: 27h [BE/High]
#   - Task_76: 18h [BE/Medium]
#   - Task_89: 5h [BE/High]
#
# E_Dev4: 70.00h, 2 tasks
#   - Task_78: 33h [BE/Disaster]
#   - Task_93: 37h [BE/Low]
#
# B_Dev6: 70.00h, 3 tasks
#   - Task_84: 25h [BE/High]
#   - Task_86: 37h [BE/Low]
#   - Task_99: 8h [BE/Medium]
#
# B_Dev7: 69.00h, 3 tasks
#   - Task_85: 8h [BE/High]
#   - Task_88: 24h [BE/Critical]
#   - Task_91: 37h [BE/Low]
